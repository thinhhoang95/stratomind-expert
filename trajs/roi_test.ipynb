# %%
import roi
import numpy as np
from matplotlib import pyplot as plt

# %%
roi.grid_ul
# Out:
# (-98.47249157403405, 33.8751727092045)

# %%
# Plot the airport and the grid
from cartopy import crs as ccrs
from cartopy import feature as cfeature

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.STATES)
ax.set_extent([-120, -70, 20, 55], crs=ccrs.PlateCarree())
ax.gridlines(draw_labels=True)
ax.set_title('Airport and grid')

# Plot the airport
ax.plot(roi.KDFW[0], roi.KDFW[1], 'r*', transform=ccrs.PlateCarree()) # lon, lat

# Plot the four corners of the grid
ax.plot(roi.grid_ul[0], roi.grid_ul[1], 'bo', transform=ccrs.PlateCarree()) # lon, lat
ax.plot(roi.grid_ur[0], roi.grid_ur[1], 'bo', transform=ccrs.PlateCarree()) # lon, lat
ax.plot(roi.grid_ll[0], roi.grid_ll[1], 'bo', transform=ccrs.PlateCarree()) # lon, lat
ax.plot(roi.grid_lr[0], roi.grid_lr[1], 'bo', transform=ccrs.PlateCarree()) # lon, lat
